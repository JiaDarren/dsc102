# %%
import dask.dataframe as dd
from dask.distributed import Client
import json
import dask

# %%
# client=Client('127.0.0.1:8786')
# client.scheduler_info()
# #dask.config.config

# %%
products = dd.read_csv("small_products_Release.csv")
reviews = dd.read_csv("small_user_reviews_Release.csv")

# %%
products.tail(1)
# Out:
#             asin           salesRank  \
# 6217  0198515294  {'Books': 1938228}
#
#                                                   imUrl   categories  \
# 6217  http://ecx.images-amazon.com/images/I/510Vg1i6...  [['Books']]
#
#                                            title  \
# 6217  Global Public Health: A New Era (Medicine)
#
#                                             description  price related brand
# 6217  "I would recommend this eminently readable and...  52.22     NaN   NaN

# %%
reviews.head(1)
# Out:
#        reviewerID        asin   reviewerName helpful  \
# 0  A2T0RJ91B0PQ03  B0016CRVLW  Gerald DeWitt  [0, 0]
#
#                                           reviewText  overall  \
# 0  Beware!  This is NOT the original single versi...      1.0
#
#                        summary  unixReviewTime   reviewTime
# 0  Poor Quality Alternate Take    1.400630e+09  05 21, 2014

# %%
products.shape[0].compute()
# Out:
# 99999

# %%
products.head()
# Out:
#          asin                 salesRank  \
# 0  0001048791        {'Books': 6334800}
# 1  0000143561   {'Movies & TV': 376041}
# 2  0000037214     {'Clothing': 1233557}
# 3  0000032069                       NaN
# 4  0000031909  {'Toys & Games': 201847}
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/51MKP0T4...
# 1  http://g-ecx.images-amazon.com/images/G/01/x-s...
# 2  http://ecx.images-amazon.com/images/I/31mCncNu...
# 3  http://ecx.images-amazon.com/images/I/51EzU6qu...
# 4  http://ecx.images-amazon.com/images/I/41xBoP0F...
#
#                                           categories  \
# 0                                        [['Books']]
# 1                        [['Movies & TV', 'Movies']]
# 2  [['Clothing, Shoes & Jewelry', 'Girls'], ['Clo...
# 3  [['Sports & Outdoors', 'Other Sports', 'Dance'...
# 4   [['Sports & Outdoors', 'Other Sports', 'Dance']]
#
#                                                title  \
# 0  The Crucible: Performed by Stuart Pankin, Jero...
# 1  Everyday Italian (with Giada de Laurentiis), V...
# 2  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...
# 3                     Adult Ballet Tutu Cheetah Pink
# 4                        Girls Ballet Tutu Neon Pink
#
#                                          description  price  \
# 0                                                NaN    NaN
# 1  3Pack DVD set - Italian Classics, Parties and ...  12.99
# 2                                                NaN   6.99
# 3                                                NaN   7.89
# 4  High quality 3 layer ballet tutu. 12 inches in...   7.00
#
#                                              related       brand
# 0                                                NaN         NaN
# 1  {'also_viewed': ['B0036FO6SI', 'B000KL8ODE', '...         NaN
# 2  {'also_viewed': ['B00JO8II76', 'B00DGN4R1Q', '...  Big Dreams
# 3  {'also_bought': ['0000032050', 'B00D0DJAEG', '...    BubuBibi
# 4  {'also_bought': ['B002BZX8Z6', 'B00JHONN1S', '...     Unknown

# %%
percentNa = (reviews.isna().mean().mean()*100 + products.isna().mean().mean()*100)/2
percentNa.compute()

#check mask""???
# Out:
# 19.697974757525355

# %%
subproducts = products[['asin', 'price']]
subreviews = reviews[['asin', 'overall']]

#optimise with left and not index on products
joined = subproducts.set_index("asin").join(subreviews.set_index("asin"), on="asin", how='inner')
#joined.head()
pcor = joined.corr()['overall']
val = pcor.compute()['price']
val
# Out:
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/pandas/core/frame.py:8280: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/lib/function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/lib/function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/pandas/core/frame.py:8280: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/lib/function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/ubuntu/dask_env/lib/python3.6/site-packages/numpy/lib/function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# -0.034585828859168014

# %%
price_prod = products['price'].describe().compute()
[price_prod['mean'], price_prod['std'], price_prod['50%'], price_prod['min'], price_prod['max']]
# Out:
# [27.726746045964067, 40.33121621403623, 16.14, 0.0, 992.75]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-10a252899e31> in <module>
# ----> 1 ddf.price.describe()
#
# NameError: name 'ddf' is not defined

# %%
def f(x):
    if isinstance(x, float):
        return x
    else:
        return x.strip("[]").split(',')[0]

numCat = products.assign(categories = lambda x: x.categories.apply(
    f,
    meta=('categories', 'str'))
                        )

numCat = numCat.groupby("categories").count()['asin']
numCat.compute()[1:]

#[1:]this removes the nan catagory
# Out:
# categories
# 'Books'                        99835
# 'CDs & Vinyl'                      9
# 'Clothing                          3
# 'Movies & TV'                     72
# 'Musical Instruments'              4
# 'Software'                         6
# 'Sports & Outdoors'                7
# 'Tools & Home Improvement'         1
# 'Toys & Games'                     5
# 'Baby'                             3
# 'Cell Phones & Accessories'        3
# 'Electronics'                      1
# 'Health & Personal Care'           1
# 'Home & Kitchen'                   2
# 'Office & School Supplies'         1
# 'Office Products'                  2
# 'Video Games'                      1
# Name: asin, dtype: int64

# %%
subR = reviews[['asin']].drop_duplicates().set_index('asin')

subP = products.set_index('asin')

iner = subR.join(subP, on="asin", how='inner').shape[0]

left = subR.join(subP, on="asin", how='left').shape[0]

print(iner)
print(left)

out = (iner == left).compute()

out

#products.set_index('asin').index
#index.difference(products.set_index('asin').index)
# Out:
# 1804
# 87295
# False

# %%
subR.join(subP, on="asin", how='inner').compute()
# Out:
#                                   salesRank  \
# asin
# 0000031887  {'Sports &amp; Outdoors': 8547}
# 000100039X                {'Books': 587803}
# 0002007770               {'Books': 2296729}
# 0002178559                {'Books': 233967}
# 0002185385               {'Books': 1571618}
# ...                                     ...
# 019562971X               {'Books': 6182918}
# 0198258461              {'Books': 10977064}
# 0198279299               {'Books': 2264501}
# 0198326769                {'Books': 755361}
# 0198506147                {'Books': 690589}
#
#                                                         imUrl  \
# asin
# 0000031887  http://ecx.images-amazon.com/images/I/314qZjYe...
# 000100039X  http://ecx.images-amazon.com/images/I/81ZKLPiv...
# 0002007770  http://ecx.images-amazon.com/images/I/511VYFJM...
# 0002178559  http://ecx.images-amazon.com/images/I/61Ufn5kW...
# 0002185385  http://ecx.images-amazon.com/images/I/41JB1K72...
# ...                                                       ...
# 019562971X                                                NaN
# 0198258461  http://ecx.images-amazon.com/images/I/416WdtZx...
# 0198279299  http://ecx.images-amazon.com/images/I/81zaHB5E...
# 0198326769  http://ecx.images-amazon.com/images/I/51HrQBjt...
# 0198506147  http://ecx.images-amazon.com/images/I/410loeev...
#
#                                                    categories  \
# asin
# 0000031887  [['Clothing, Shoes & Jewelry', 'Girls', 'Cloth...
# 000100039X                                        [['Books']]
# 0002007770                                        [['Books']]
# 0002178559                                        [['Books']]
# 0002185385                                        [['Books']]
# ...                                                       ...
# 019562971X                                        [['Books']]
# 0198258461                                        [['Books']]
# 0198279299                                        [['Books']]
# 0198326769                                        [['Books']]
# 0198506147                                        [['Books']]
#
#                                                         title  \
# asin
# 0000031887                         Ballet Dress-Up Fairy Tutu
# 000100039X                                        The Prophet
# 0002007770                                Water For Elephants
# 0002178559   Demanding the Impossible: A History of Anarchism
# 0002185385  Harvey Penick's Little Red Golf Book: Lessons ...
# ...                                                       ...
# 019562971X  Above the Forest: A Study of Andamanese Ethnoa...
# 0198258461  The Cyprus Question and the Turkish Position i...
# 0198279299  1948 and After: Israel and the Palestinians (C...
# 0198326769                     The Boy in the Striped Pyjamas
# 0198506147          The Genius of Science: A Portrait Gallery
#
#                                                   description   price  \
# asin
# 0000031887  This adorable basic ballerina tutu is perfect ...    6.79
# 000100039X  In a distant, timeless place, a mysterious pro...    3.99
# 0002007770                                                NaN    8.52
# 0002178559  The goal of an egalitarian, communal society h...   12.99
# 0002185385  Before titanium drivers, before oversized head...   10.99
# ...                                                       ...     ...
# 019562971X                                                NaN     NaN
# 0198258461  Zaim M. Necatigil is former Attorney-General o...  188.10
# 0198279299  "For scholars interested in the Palestine of t...   57.59
# 0198326769  Book DescriptionThis work was set in Berlin, 1...    4.99
# 0198506147  Physics might seem part of an alien culture to...   13.99
#
#                                                       related           brand
# asin
# 0000031887  {'also_bought': ['0000031852', '0000031895', '...  Boutique Cutie
# 000100039X  {'also_bought': ['1851686274', '0785830618', '...             NaN
# 0002007770  {'also_bought': ['0399155341', '1573222453', '...             NaN
# 0002178559  {'also_viewed': ['0853451753', '0192804774', '...             NaN
# 0002185385  {'also_bought': ['0671612972', '0767903447', '...             NaN
# ...                                                       ...             ...
# 019562971X                                                NaN             NaN
# 0198258461                                                NaN             NaN
# 0198279299  {'also_viewed': ['0679744754', '0300126964', '...             NaN
# 0198326769  {'also_bought': ['1561378380', '158013176X', '...             NaN
# 0198506147  {'also_bought': ['0691012431', '019853907X', '...             NaN
#
# [1804 rows x 8 columns]
